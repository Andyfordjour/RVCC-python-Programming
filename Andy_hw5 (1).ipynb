# %% [markdown]
# ### home work 5
# ### Auhtor Andy fordjour
# ### Problem 1

# %%
#Author : Andy Forjour
#A program to display various games
def turtle():
    """
         function import turtle and draws a poligon
         A polygon is a six sided figure
         In this function I add a pencolor of red,blue,yellow and fillcolor of green
    """

    import turtle as t

    t.pencolor("red")
    t.fillcolor("green")
    t.begin_fill()
    t.width(5)
    t.forward(100)
    t.width(5)
    t.right(300)
    t.forward(100)
    t.width(5)
    t.pencolor("blue")
    t.right(300)
    t.forward(100)
    t.width(5)
    t.right(300)
    t.forward(100)
    t.width(5)
    t.pencolor("yellow")
    t.right(300)
    t.forward(100)
    t.width(5)
    t.right(300)
    t.forward(100)
    t.width(5)
    t.right(300)
    t.end_fill()

def rock_paper_scissor():
    """
        This module ask a user to play the rock,  paper and scissors game with a computer.
        The computer randomly select any of the three options to compete withe user and displays
        a win , lose or tie after each game.
    """
    import random
    print("Welcome to my game!")

    player = input("Do you want to be 'rock', 'paper', or 'scissors'? ")
    print("You are ", player)

    computer = random.choice(['rock', 'paper', 'scissors'])
    print("The computer has", computer)

    if player == computer:
        print("It's a TIE!")

    elif player == 'rock':
        if computer =='tree':
            print("You WIN!")
        else:
            print("You LOSE")

    elif player == 'scissors': 
        if computer =='rock':
            print("You LOSE!")
        else:
            print("You WIN!")

    elif player == 'paper' :
        if computer =='scissors':
            print("You LOSE!")
        else:
            print("You WIN!")
    
    
def dating_game():
    # dating program
    # author Andy fordjour
    """
    In this molude we ask for the users age and thier love_interest age.
    Both inputs will calculate and check if that person is not too old for you  
    The vairant ask if you like a celebrity or not and do not override the age but instead use the age for validation
    """
    your_age = int(input("Enter your age: "))
    love_interest_age = int(input("Enter LI age: "))


    if love_interest_age < your_age / 2 + 7:
        print("You are creepy... find someone your own age!")


    elif love_interest_age >= your_age-7 * 2:
    
        variant = str(input("Do you want a celebrity: type 'yes' or 'no': "))
    
        if variant =="yes":
        
            print("Great! enjoy your celebrity life style")
        else :
            print("Great! I see you like a simple life!")
        
        print("Not too old for you.. you are good to go")

def main():
    """
    The main fuction provide the user a menu of the game to be played and ask them to choose form the manu 
    """
    print("Hello welcome to the game")
    print()
    
    choice ="y"
    while choice.lower()=="y":
    
    #user input
        print("Choose one of these games\n")
        user = int(input("Enter 1 turtle game" +
                         " or Enter 2 for rock paper and scissors game or 3 for dating game: "))
        
        if user == 1:
            user = turtle()
        elif user == 2:
            user = rock_paper_scissor()
        else:
            user = dating_game()
       
        choice = input("\nwould you like to see the menu agian? (y/n): ")
        print()
        
    print("Good Bye!!")
    
if __name__=="__main__":
    main()
# Out:
# Hello welcome to the game
#
# Choose one of these games
#
# Enter 1 turtle game or Enter 2 for rock paper and scissors game or 3 for dating game: 1
#
# would you like to see the menu agian? (y/n): y
#
# Choose one of these games
#
# Enter 1 turtle game or Enter 2 for rock paper and scissors game or 3 for dating game: 3
# Enter your age: 40
# Enter LI age: 10
# You are creepy... find someone your own age!
#
# would you like to see the menu agian? (y/n): n
#
# Good Bye!!

# %% [markdown]
# ### Problem 2
# ### Author Andy fordjour

# %%
###Author Andy fordjour

def cube(x):
    """
        The cube function ask for a value and return the cube of the value
    """
    x= x**3
    return x

def closer_to_44(x,y):
    """
        The closer to 44 function ask for x and y values and output the number closer to 44
    """
    #x= int(input("Enter a number: "))
    #y= int(input("Enter a number: "))
    
    a = abs(x-44)
    b = abs(y-44)
    
    if a<=b:
        print("The number closer to 44 is ",x)
    else:
        print("The number closer to 44 is ",y)
    
    
def sum_dice_roll():
    """
        The sum dice roll function import two random numbers from a range of 1 to 6
        and add them together and return the results
    """
    import random
    
    x = random.randint(1,6)
    y = random.randint(1,6)
    
    results = x+y
    
    print("die 1: ",x)
    print("die 2: ",y)
    
    return print("The sum of the dice numbers obtained is ",results)

def main():
    """
        The main ask for an x value to calculate the cube.
        It also calls the function closer_to_44 and sum_dice_roll to display it output.
        Which later ask the user either to continue or not
    """
    
    choice ="y"
    while choice.lower()=="y":
        print("The cube calculator")
        
        x= int(input("Enter an x value: "))
        x = cube(x)
        print("The cube for your x value =",x)
        
        print("\nCloser to 44 calculator")
        
        x= int(input("Enter a number: "))
        y= int(input("Enter another number: "))
        result = closer_to_44(x,y)
        
        print()
        print("Sum of dice rolled")
        sum_dice_roll()
        
        
        choice = input("\nwould you like to continue? (y/n): ")
        print()
    print("Good Bye!!")
    
if __name__=="__main__":
    main()
# Out:
# The cube calculator
# Enter an x value: 3
# The cube for your x value = 27
#
# Closer to 44 calculator
# Enter a number: 44
# Enter another number: 20
# The number closer to 44 is  44
#
# Sum of dice rolled
# die 1:  3
# die 2:  6
# The sum of the dice numbers obtained is  9
#
# would you like to continue? (y/n): n
#
# Good Bye!!
