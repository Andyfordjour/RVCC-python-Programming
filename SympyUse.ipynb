# %% [markdown]
# ### Sympy
# ### The sympy package is for symbolic mathematics.  It can plot
# ### the function and compute formulas.

# %%
# from Chapter 2 p. 69
from sympy import *

# display commands in mathematical notation
init_printing()

# convert the String  expression into a symbolic expression
# not python code
f = sympify("x ** 2 * sin(x)")
f

#plot(f)
# Out:
#  2
# x ⋅sin(x)

# %%
from sympy import *

# display commands in mathematical notation
init_printing()

# convert the string expression into a symbolic expression
# not python code
f = sympify("x ** 2 * sin(x)")
f

plot(f)

# %%
from sympy import *

# display commands in mathematical notation
init_printing()

# convert the string expression into a symbolic expression
# not python code
f = sympify("x ** 2 * x")
f
#plot(f)
