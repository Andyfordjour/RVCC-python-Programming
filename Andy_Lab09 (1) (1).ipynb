# %% [markdown]
# ### lab 9
# ### Author Andy fordjour
# ### problem 2

# %%
def display_menu():
    """
    Displays_menu function displays the menu of the various functions to be executed
    """
    print("COMMAND MENU")
    print("list - List all movies")
    print("add - Add a movie")
    print("del - Delete a movie")
    print("exit - exit program")
    
def list(movie_list): 
    """
    The list function displays the list of contacts by their first names
    """
    i = 1
    print()
    for movie in movie_list:
        print(i, ". " , movie)
        i += 1
        
    print()
    
def add(movie_list):
     """
    The add function add a new contact to the contact list
    """
    name = input("Movie Name: ")
    year = input("movie year: ")
    movie_list.append({'name':name, 'year':year})
    
    
    print(name + " was added to the movie list.\n")
    
def delete(movie_list):
    """
    The delete function ask for the contact number and delect the contact from the list
    """
    number = int(input("Movie number: "))
    if number < 1 or number > len(movie_list):
        print("Invalid movie number.\n")
    else:
        movie_list= movie_list.pop(number-1)
        print(movie_list["name"] ," was deleted.\n")
              
def main():
    """
    The main function ask user to select from menu and displays the command 
    """
    movie_list = [{"name":"A Star is Born","year":2018},
                  {"name": "An old Man and a Gun","year":2018},
                 {"name":"The spy Who Dumped Me","year":2017}]
              
    display_menu()
    command = input("Enter Command: ")
        
    while (command.lower() != "exit"):
        
        if command.lower() == "list":
            list(movie_list)
            display_menu()
        elif command.lower() == "add":
            add(movie_list)
            display_menu()
        elif command.lower() == "del":
            delete(movie_list)
            display_menu()
        else:
            print("Not a valid command.  Please try again.\n")
            
        command = input("Enter Command: ")
               
    print("You'll be back!")     
        
if __name__ == "__main__":
    main()
# Out:
# COMMAND MENU
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - exit program
# Enter Command: list
#
# 1 .  {'name': 'A Star is Born', 'year': 2018}
# 2 .  {'name': 'An old Man and a Gun', 'year': 2018}
# 3 .  {'name': 'The spy Who Dumped Me', 'year': 2017}
#
# COMMAND MENU
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - exit program
# Enter Command: del
# Movie number: 2
# An old Man and a Gun  was deleted.
#
# COMMAND MENU
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - exit program
# Enter Command: list
#
# 1 .  {'name': 'A Star is Born', 'year': 2018}
# 2 .  {'name': 'The spy Who Dumped Me', 'year': 2017}
#
# COMMAND MENU
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - exit program
# Enter Command: exit
# You'll be back!

# %%
def get_full_name():
    bad_name = True
    while bad_name:
        name = input("Enter full name: ").strip()
        if " " in name:
            bad_name = False
            return name
        else:
            print("You must enter your full name.")
            
def get_password():
    bad_pwd = True
    while bad_pwd:
        password = input("Enter password:  ").strip()
        digit = False
        cap_letter = False
        for char in password:
            if char.isdigit():
                digit = True
            elif char.isupper():
                cap_letter = True
        if digit == False or cap_letter == False or len(password) < 8:
            print("Password must be 8 characters or more \n" +
                  "with at least one digit and one uppercase letter.")
        else:
            bad_pwd = False
            return password
        
def get_first_name(full_name):
    index1 = full_name.find(" ")
    first_name = full_name[:index1]
    return first_name


def get_email():
    bad_email = True
    while bad_email:
        email = input("Enter email: ")
        if "@" in email and email.endswith(".com")::
            bad_name = False
            return email
        else:
            print("You must enter a valid email.")
            
def get_number():
    bad_number =True
    while bad_number:
        tn = int(input("Enter phone number: "))
        if len(tn)==10:
            tn = tn.replace("-", "")
            tn = tn.replace("-","",1) 
            tn = "(" + tn[:3] + ") " + tn[3:]
            bad_number = False
            return tn
    else:
        print("enter a valid number")
            

def main():
    full_name = get_full_name()
    print()
    
    password = get_password()
    print()
    
    email = get_email()
    print()
    
    number =get_number()
    print()
    
    first_name = get_first_name(full_name)
    print("Hi " + first_name + ", thanks for creating an account.")
    
if __name__ == "__main__":
    main()

# %%
bad_number =True
while bad_number:
    tn = input("Enter phone number: ")
    if len(tn)==10:
        tn = tn.replace("-", "")
        #tn = tn.replace("-","",1) 
        tn = "(" + tn[:3] + ") " + tn[3:]
        tn = tn.replace("-","",1)
        bad_number = False
        print(tn)
# Out:
# Enter phone number: 0123456789
# (012) 3456789
