# %%
# Object oriented programming

class Product:
    
    # constructor that initialized three attributes
    def __init__(self, name, price, discountPercent):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two  attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()

# %%
# Object Oriented Programming

class Product:
    
    # constructor that initialized three attributes
    def __init__(self, name, price, discountPercent):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
# create two product objects
product1 = Product('Stanley 13 Ounce Wood Hammer', 12.99, 62)
product2 = Product('National Hardware 3/4 Wire Nails', 5.06, 0)

# print will only return the address of the object
print(product1)

# need to print individual data for product1
print("Name:             {:s}".format(product1.name))
print("Price:            {:.2f}".format(product1.price))
print("Discount percent: {:d}%".format(product1.discountPercent))
print("Discount amount:  {:f}%".format(product1.getDiscountAmount()))
print("Discount price:   {:f}%".format(product1.getDiscountPrice()))
# Out:
# ...
# Name:             Stanley 13 Ounce Wood Hammer
# Price:            12.99
# Discount percent: 62%
# Discount amount:  8.053800%
# Discount price:   4.936200%

# %%
class Product:
    
    # constructor that initializes three attributes
    def __init__(self):
        self.name = ""
        self.price = 0.0
        self.discountPercent = 0
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
# create a product object using the constructor
product = Product()

# set the attributes of the object
product.name = "I'd rather be a hammer than a nail!"
product.price = 12.99
product.discountPercent = 62

# need to print individual data for product1
print("Name:             {:s}".format(product.name))
print("Price:            {:.2f}".format(product.price))
print("Discount percent: {:d}%".format(product.discountPercent))
print("Discount amount:  {:.2f}".format(product.getDiscountAmount()))
print("Discount price:   {:.2f}".format(product.getDiscountPrice()))
# Out:
# Name:             I'd rather be a hammer than a nail!
# Price:            12.99
# Discount percent: 62%
# Discount amount:  8.05
# Discount price:   4.94

# %%
# using a constructor with default parameters

class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
# create a product object using the constructor
product = Product("If I had a hammer!")

# need to print individual data for product1
print("Name:             {:s}".format(product.name))
print("Price:            {:.2f}".format(product.price))
print("Discount percent: {:d}%".format(product.discountPercent))
print("Discount amount:  {:.2f}%".format(product.getDiscountAmount()))
print("Discount price:   {:.2f}%".format(product.getDiscountPrice()))

# %%
# using a method that accepts a parameter

class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 200.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method that accepts a parameter
    def getPriceStr(self, country):
        priceStr = "{:.2f}".format(self.price)
        if country == "US":
            priceStr += " USD"
        elif country == "DE":
            priceStr += " EUR"
        return priceStr
    
# create a product object using the constructor
product = Product("If I had a hammer!")

# need to print individual data for product1
print("Name:             {:s}".format(product.name))
print("Price:            {:.2f}".format(product.price))
print("Discount percent: {:d}%".format(product.discountPercent))
print("Discount amount:  {:.2f}".format(product.getDiscountAmount()))
print("Discount price:   {:.2f}".format(product.getDiscountPrice()))

# use the new method to display a price
print("Price: " + product.getPriceStr("US"))
# Out:
# Name:             If I had a hammer!
# Price:            200.00
# Discount percent: 0%
# Discount amount:  0.00
# Discount price:   200.00
# Price: 200.00 USD

# %%
# Create a Product Viewer Program

class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 200.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
def show_products(products):
    print("PRODUCTS")
    for i in range(len(products)):
        product = products[i]
        print(str(i+1) + ". " + product.name)
    print()
    
def show_product(product):
    print("PRODUCT DATA")
    print("Name:             {:s}".format(product.name))
    print("Price:            {:.2f}".format(product.price))
    print("Discount percent: {:d}%".format(product.discountPercent))
    print("Discount amount:  {:.2f}".format(product.getDiscountAmount()))
    print("Discount price:   {:.2f}".format(product.getDiscountPrice()))
    print()
    
def main():
    print("The Product Viewer program:")
    print()
    
    # a tuple of Product objects
    products = (Product("Stanley 13 Ounce Wood Hammer", 12.99, 62),
                Product('National Hardware 3/4" Wire Nails', 5.06, 0),
                Product('Economy Duct Tape, 60 yds, Silver', 7.24, 0))
    
    show_products(products)
    
    choice = "y"
    while choice == "y":
        number = int(input("Enter product number: "))
        print()
        
        product = products[number - 1]
        show_product(product)
        
        choice = input("View another product? y/n): ")
        print()
        if choice != "y":
            print("Bye for now!")
            
if __name__ == "__main__":
    main()
# Out:
# The Product Viewer program:
#
# PRODUCTS
# 1. Stanley 13 Ounce Wood Hammer
# 2. National Hardware 3/4" Wire Nails
# 3. Economy Duct Tape, 60 yds, Silver
#
# Enter product number: 1
#
# PRODUCT DATA
# Name:             Stanley 13 Ounce Wood Hammer
# Price:            12.99
# Discount percent: 62%
# Discount amount:  8.05
# Discount price:   4.94
#
# View another product? y/n): y
#
# Enter product number: 2
#
# PRODUCT DATA
# Name:             National Hardware 3/4" Wire Nails
# Price:            5.06
# Discount percent: 0%
# Discount amount:  0.00
# Discount price:   5.06
#
# View another product? y/n): y
#
# Enter product number: 3
#
# PRODUCT DATA
# Name:             Economy Duct Tape, 60 yds, Silver
# Price:            7.24
# Discount percent: 0%
# Discount amount:  0.00
# Discount price:   7.24
#
# View another product? y/n): n
#
# Bye for now!

# %%
# Dice roller - object composition

import random

class Die:
    def __init__(self):
        self.value = 1
        
    def roll(self):
        self.value = random.randrange(1,7)
        
class Dice:
    def __init__(self):
        self.list = []
        
    def addDie(self, die):
        self.list.append(die)
        
    def rollAll(self):
        for die in self.list:
            die.roll()
            
def main():
    print("The Dice Roller Program")
    print()
    
    # get the number of dice from the user
    count = int(input("Enter the number of dice to roll: "))
    
    # Dice object and add Die objects to it
    dice = Dice()
    for i in range(count):
        die = Die()
        dice.addDie(die)
        
    choice = "y"   
    while choice == "y":
        # roll the dice
        dice.rollAll()
        print("YOUR ROLL: ", end = "")
        for die in dice.list:
            print(die.value, end = " ")
        print("\n")
        
        choice = input("Roll again? (y/n): ")
        if choice != "y":
            print("Bye!")
          
            
if __name__ == "__main__":
    main()
# Out:
# The Dice Roller Program
#
# Enter the number of dice to roll: 5
# YOUR ROLL: 6 3 4 3 6
#
# Roll again? (y/n): y
# YOUR ROLL: 6 1 5 4 1
#
# Roll again? (y/n): n
# Bye!

# %%
# encapsulation

import random

class Die:
    def __init__(self):
        # use a private attribut named __value
        self.__value = 1
        
    def getValue(self):
        return self.__value
    
    def roll(self):
        self.__value = random.randrange(1,7)
        
def main():
    die = Die()
    #die.__value = 10
    die.roll()
    print("Die:", die.getValue())
    
if __name__ == "__main__":
    main()
# Out:
# Die: 5

# %%
# using properties

class Die:
    def __init__(self):
        self.__value = 1
        
    @property
    def value(self):
        return self.__value
    
    @value.setter
    def value(self, value):
        if value < 1 or value > 6:
            raise ValueError("Die value must be from 1 to 6.")
        else:
            self.__value = value
            
            
def main():
    die = Die()
    #die.value = 8
    die.value = 6
    print("Die:", die.value)
    
if __name__ == "__main__":
    main()
# Out:
# Die: 6

# %%
# Die and Dice encapsulated - slide 45

import random

class Die:
    def __init__(self):
        self.__value = 1
        
    # only a get so it is read only
    @property
    def value(self):
        return self.__value
    
    def roll(self):
        self.__value = random.randrange(1,7)
        
class Dice:
    def __init__(self):
        self.__list = []
        
    # only a get and return an immutable object to make it read only
    @property
    def list(self):
        dice_tuple = tuple(self.__list)
        return dice_tuple
    
    def addDie(self, die):
        self.__list.append(die)
        
    def rollAll(self):
        for die in self.__list:
            die.roll()
            
def main():
    print("The Dice Roller Program")
    print()
    
    # get the number of dice from the user
    count = int(input("Enter the number of dice to roll: "))
    
    # Dice object and add Die objects to it
    dice = Dice()
    for i in range(count):
        die = Die()
        dice.addDie(die)
       
    choice = "y"
    while choice == "y":
        # roll the dice
        dice.rollAll()
        print("YOUR ROLL: ", end = "")
        for die in dice.list:
            print(die.value, end = " ")
        print("\n")
        
        choice = input("Roll again? (y/n): ")
        if choice != "y":
            print("Bye!")
          
if __name__ == "__main__":
    main()
# Out:
# The Dice Roller Program
#
# Enter the number of dice to roll: 2
# YOUR ROLL: 3 1
#
# Roll again? (y/n): y
# YOUR ROLL: 1 5
#
# Roll again? (y/n): n
# Bye!

# %%
# Encapsulating the product class

class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price   # passes price param to price setter
        self.discountPercent = discountPercent
        
    # using property, get the price
    @property
    def price(self):
        return self.__price
    
    @price.setter
    def price(self, price):
        if price < 0:
            raise ValueError("Price can't be less than o")
        else:
            self.__price = price
    
        
    # method that uses two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    

    
def main():
    #product = Product()
    #product.price = -11.50
    product =  Product("Hammer", -11.50)
    
    # need to print individual data for product
    print("Name:             {:s}".format(product.name))
    print("Price:            {:.2f}".format(product.price))
    print("Discount percent: {:d}%".format(product.discountPercent))
    print("Discount amount:  {:.2f}%".format(product.getDiscountAmount()))
    print("Discount price:   {:.2f}%".format(product.getDiscountPrice()))
            
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8f405542a15f> in <module>()
#      45
#      46 if __name__ == "__main__":
# ---> 47     main()
#
# <ipython-input-6-8f405542a15f> in main()
#      35     #product = Product()
#      36     #product.price = -11.50
# ---> 37     product =  Product("Hammer", -11.50)
#      38
#      39     # need to print individual data for product
#
# <ipython-input-6-8f405542a15f> in __init__(self, name, price, discountPercent)
#       6     def __init__(self, name = "", price = 0.0, discountPercent = 0):
#       7         self.name = name
# ----> 8         self.price = price   # passes price param to price setter
#       9         self.discountPercent = discountPercent
#      10
#
# <ipython-input-6-8f405542a15f> in price(self, price)
#      17     def price(self, price):
#      18         if price < 0:
# ...

# %%
# Using is, is not

class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price   # passes price param to price setter
        self.discountPercent = discountPercent
        
    # using property, get the price
    @property
    def price(self):
        return self.__price
    
    @price.setter
    def price(self, price):
        if price < 0:
            raise ValueError("Price can't be less than o")
        else:
            self.__price = price
    
        
    # method that uses two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    

    
def main():

    prod1 =  Product("Hammer", 12.50)
    prod2 = Product("Hammer", 12.50)
    
    if prod1 is prod2:
        print("They are 1 product!")
    if prod1 is not prod2:
        print("They are 2 different products!")
    

            
if __name__ == "__main__":
    main()
# Out:
# They are 2 different products!
