# %%
# This program displays a simple line graph
import matplotlib.pyplot as plt

def main():
    # Create lists with X and Y coordinates of each data point
    x_coords = [0, 1, 2, 3, 4]
    y_coords = [0, 3, 1, 5, 2]
    
    # Build the line graph and set dot as marker
    plt.plot(x_coords, y_coords, marker = "o")
    
    # Add a title
    plt.title("Example line graph")
    
    # Add a label to the x-axis
    plt.xlabel("This is the X axis")
    
    # Add a label to the y-axis
    plt.ylabel("This is the Y axis")
    
    # Add a grid
    plt.grid(True)
    
    # Display the line graph
    plt.show()
    
# Call the main funcntion
if __name__ == "__main__":
    main()

# %%
# draw a simple bar chart

import matplotlib.pyplot as plt

def main():
    # Create a list with the X coordinates of each bar's left edge
    left_edges = [0, 10, 20, 30, 40]
    
    # Create a list with the heights of each bar - Y coordinates
    heights = [100, 200, 300, 400, 500]
    
    # Create a variable for the bar width
    #bar_width = 5
    
    # Build the bar chart
    plt.bar(left_edges, heights)
    #plt.bar(left_edges, heights, bar_width)

    
    # Display the bar chart
    plt.show()
    
if __name__ == "__main__":
    main()

# %%
# draw a simple bar chart

import matplotlib.pyplot as plt

def main():
    # Create a list with the X coordinates of each bar's left edge
    left_edges = [0, 10, 20, 30, 40]
    
    # Create a list iwht the heights of each bar
    heights = [100, 200, 300, 400, 500]
    
    # Create a variable for the bar width
    bar_width = 5
    
    # Add a title
    plt.title('Sales by Year')
    
    # Add labels to the axes
    plt.xlabel('Year')
    plt.ylabel('Sales')
    
    # Customize the tick marks
    plt.xticks([0, 10, 20, 30, 40],
               ['2016', '2017', '2018', '2019', '2020'])
    plt.yticks([0, 100, 200, 300, 400, 500],
               ['$0m', '$1m', '$2m', '$3m', '$4m', '$5m'])
    
    # Build the bar chart
    plt.bar(left_edges, heights, bar_width, 
            color=('r', 'g', 'b', 'w', 'k'))
    
    # Display the bar chart
    plt.show()
    
if __name__ == "__main__":
    main()

# %%
# display a simple pie chart

import matplotlib.pyplot as plt

def main():
    
    # create a list of values
    values = [20, 60, 80, 40]
    
    # create a pie chart from the values
    plt.pie(values)
    
    # display the pie chart
    plt.show()
    
if __name__ == "__main__":
    main()

# %%
# display a simple pie chart

import matplotlib.pyplot as plt

def main():
    
    # create a list of sales amounts
    sales = [100, 400, 300, 600]
    
    # create a list of labels for the slices
    slice_labels = ["1st Qtr", "2nd Qtr", "3rd Qtr", "4th Qtr"]
    
    # create a pie chart from the values
    plt.pie(sales, labels=slice_labels)
    
    # add a title
    plt.title("Sales by Quarter")
    
    # display the pie chart
    plt.show()
    
if __name__ == "__main__":
    main()

# %%
# display a simple pie chart

import matplotlib.pyplot as plt

def main():
    
    # create a list of sales amounts
    sales = [100, 400, 300, 600]
    
    # create a list of labels for the slices
    slice_labels = ["1st Qtr", "2nd Qtr", "3rd Qtr", "4th Qtr"]
    
    # create a pie chart from the values
    plt.pie(sales, labels=slice_labels, colors =("m", "b", "r", "y"))
    
    # add a title
    plt.title("Sales by Quarter")
    
    # display the pie chart
    plt.show()
    
if __name__ == "__main__":
    main()
