# %%
# The code for the Product superclass
class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method thaat returns a description of the product
    def getDescription(self):
        return self.name
                 
# The code for the Book subclass
class Book(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, author = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.author = author
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " by " + self.author

# %%
# Shows Polymorphism 
# The code for the Product superclass
class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method thaat returns the author name
    def getDescription(self):
        return self.name
    
# code for the Book Subclass
class Book(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, author = ""):
        
        # first call the constructor of the superclass
        #Product.__init__(self, name, price, discountPercent)
        super().__init__(name, price, discountPercent)
        
        # set the author
        self.author = author
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " by " + self.author
    
# The code for the Movie subclass
class Movie(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, year = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.year = year
        
    # override the getDescription method
    def getDescription(self):
        #return Product.getDescription(self) + " (" + str(self.year) + ")"
        return super().getDescription() + " (" + str(self.year) + ")"

     
def show_products(products):
    print("PRODUCTS")
    for product in products:
        print(product.getDescription())
    print()
    
def main():
    # a tuple of product objects
    products = (Product('Stanley 13 Ounce Wood Hammer', 12.99, 62),
                Book("Gone Girl", 15.95, 34, "John Jones"),
                Movie("The Spy Who Dumped Me - DVD", 21.99, 14, 2018))
    show_products(products)
    
if __name__ == "__main__":
    main()
# Out:
# PRODUCTS
# Stanley 13 Ounce Wood Hammer
# Gone Girl by John Jones
# The Spy Who Dumped Me - DVD (2018)

# %%
# using isinstance()
# The code for the Product superclass
class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method thaat returns the author name
    def getDescription(self):
        return self.name
    

# code for the Book Subclass
class Book(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, author = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.author = author
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " by " + self.author
    
# The code for the Movie subclass
class Movie(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, year = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.year = year
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " (" + str(self.year) + ")"
    
def show_product(product):
    print("PRODUCT DATA")
    print("Name:              ", product.name)
    if isinstance(product, Book):
        print("Author:                       ", product.author)
    if isinstance(product, Movie):
        print("Year:              ", product.year)
    print("Discount price:     {:.2f}".format(product.getDiscountPrice()))

    
def main():
    product1 = Product("Stanley 13 Ounce Wood Hammer", 12.99, 62)
    show_product(product1)
    print()
    
    product2 = Movie("The Spy Who Dumped Me - DVD", 21.99, 14, 2018)
    show_product(product2)
    
if __name__ == "__main__":
    main()
# Out:
# PRODUCT DATA
# Name:               Stanley 13 Ounce Wood Hammer
# Discount price:     4.94
#
# PRODUCT DATA
# Name:               The Spy Who Dumped Me - DVD
# Year:               2018
# Discount price:     18.91

# %%
# user interface and product viewer module
# The code for the Product superclass
class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method thaat returns the author name
    def getDescription(self):
        return self.name
    

# code for the Book Subclass
class Book(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, author = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.author = author
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " by " + self.author
    
# The code for the Movie subclass
class Movie(Product):
    def __init__(self, name = "", price = 0.0, discountPercent = 0, year = ""):
        
        # first call the constructor of the superclass
        Product.__init__(self, name, price, discountPercent)
        
        # set the author
        self.year = year
        
    # override the getDescription method
    def getDescription(self):
        return Product.getDescription(self) + " (" + str(self.year) + ")"
    
def show_product(product):
    print("PRODUCT DATA")
    print("Name:              ", product.name)
    if isinstance(product, Book):
        print("Author:                       ", product.author)
    if isinstance(product, Movie):
        print("Year:              ", product.year)
    print("Discount price:     {:.2f}".format(product.getDiscountPrice()))

def show_products(products):
    print("PRODUCTS")
    for i in range(len(products)):
        product = products[i]
        print(str(i+1) + ". " + product.getDescription())
    print()
        
def main():
    print("The Product Viewer program")
    print()
    # a tuple of product objects
    products = (Product('Stanley 13 Ounce Wood Hammer', 12.99, 62),
                Book("Gone Girl", 15.95, 34, "John Jones"),
                Movie("The Spy Who Dumped Me - DVD", 21.99, 14, 2018))
    show_products(products)

    again = True
    while again:
        number = int(input("Enter product number: "))
        print()
        
        product = products[number - 1]
        show_product(product)
        
        choice = input("Continue? (y/n): ")
        print()
        if choice.lower() != "y":
            again = False
    
if __name__ == "__main__":
    main()
# Out:
# The Product Viewer program
#
# PRODUCTS
# 1. Stanley 13 Ounce Wood Hammer
# 2. Gone Girl by John Jones
# 3. The Spy Who Dumped Me - DVD (2018)
#
# Enter product number: 1
#
# PRODUCT DATA
# Name:               Stanley 13 Ounce Wood Hammer
# Discount price:     4.94
# Continue? (y/n): y
#
# Enter product number: 3
#
# PRODUCT DATA
# Name:               The Spy Who Dumped Me - DVD
# Year:               2018
# Discount price:     18.91
# Continue? (y/n): n

# %%
# The code for the Product superclass
class Product:
    
    # constructor that initializes three attributes
    def __init__(self, name = "", price = 0.0, discountPercent = 0):
        self.name = name
        self.price = price
        self.discountPercent = discountPercent
        
    # method that uses two two attributes to perform a calculation
    def getDiscountAmount(self):
        return self.price * self.discountPercent / 100
    
    # method that calls another method to perform a calculation
    def getDiscountPrice(self):
        return self.price - self.getDiscountAmount()
    
    # method thaat returns the author name
    def getDescription(self):
        return self.name
    
    # override the __str__ method
    def __str__(self):
        #return self.name + "|" + str(self.price) + "|" + \
          # str(self.discountPercent)
        return self.getDescription()


def main():
    product = Product("Stanley 13 Ounce Wood Hammer", 12.99, 62)
    print(product)
    
if __name__ == "__main__":
    main()
# Out:
# Stanley 13 Ounce Wood Hammer

# %%
import random

class Die:
    def __init__(self):
        self.__value = 1
        
    @property #ready-only!
    def value(self):
        return self.__value
    
    def roll(self):
        self.__value = random.randrage(1, 7)
        
    # get a string representation of the object
    def __str__(self):
        return str(self.__value)
    
# using iter()
class Dice:
    def __init__(self):
        self.__list = []
        
    def addDie(self, die):
        self.__list.append(die)
        
    def rollAll(self):
        for die in self.__list:
            die.roll()
            
    # define the Dice object as te iterator
    def __iter__(self):
        # initialize index for each iteration
        self.__index = -1
        return self
    
    # define the method that gets the next Die object
    def __next__(self):
        if self.__index >= len(self.__list) - 1:
            raise StopIteration()
        self.__index += 1
        die = self.__list[self.__index]
        return die
    
def main():
    dice = Dice()
    for i in range(5):
        die = Die()
        dice.addDie(die)
    
    for die in dice:             # before - for die in dice.getTuple()==> change due to __iter__()
        print(die, end = " ")    # before - print(die.value, )        ==> change due to __str__()

if __name__ == "__main__":
    main()
