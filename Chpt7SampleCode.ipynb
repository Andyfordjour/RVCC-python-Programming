# %%
# Linda Yang
# working with files
pet_members = ["Munchie Pooski", "Koda Kakes", "Princess Vi", "Kokie Puffs"]
with open("petMembers.txt", "w") as file:
    for pet in pet_members:
        file.write(pet + "\n")

file.close()

# %%
members = []
with open("petMembers.txt") as infile:
    for line in infile:
        line = line.replace("\n", "")
        members.append(line)
        
infile.close()
        
print(members)
# Out:
# ['Munchie Pooski', 'Koda Kakes', 'Princess Vi', 'Kokie Puffs']

# %%
years = [1985, 1997, 2000, 2003, 2018]
with open("years.txt", "w") as years_file:
    for year in years:
        years_file.write(str(year) + "\n") 
        
new_years = []
with open("years.txt") as infile:
    for line in infile:
        line = line.replace("\n", "")
        new_years.append(int(line))
        
print(new_years)
# Out:
# [1985, 1997, 2000, 2003, 2018]

# %%
# make filename a global variable
# This file must already exist for this work!!!!!!
FILENAME = "movies.txt"

def write_movies(movie_list):
    with open(FILENAME, "w") as file:
        for movie in movie_list:
            file.write(movie + "\n")
            
def read_movies():
    movie_list = []
    with open(FILENAME) as file:
        for line in file:
            line = line.replace("\n", "")
            movie_list.append(line)
    return(movie_list)

def list_movies(movie_list):
    for i in range(len(movie_list)):
        movie = movie_list[i]
        print(str(i+1) + ". " + movie)       
    print()
    
def add_movie(movie_list):
    movie = input("Movie Name: ")
    movie_list.append(movie)
    write_movies(movie_list)
    print(movie + " was added to the movie list.\n")
    
def delete_movie(movie_list):
    number = int(input("Movie number: "))
    if number < 1 or number > len(movie_list):
        print("Invalid movie number.\n")
    else:
        movie = movie_list.pop(number-1)
        write_movies(movie_list)
        print(movie + " was deleted.\n")
        
def display_menu():
    print("The Movie  List Program\n")
    print("list - List all movies")
    print("add - Add a movie")
    print("del - Delete a movie")
    print("exit - Exit program")
    
        

def main():
    
    movie_list = read_movies()
    display_menu()
    command = input("Enter Command: ")
        
    while (command.lower() != "exit"):
        if command.lower() == "list":
            list_movies(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "add":
            add_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "del":
            delete_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "exit":
            continue
        else:
            print("Not a valid command.  Please try again.\n")
            command = input("Enter Command: ")
               
    print("You'll be back!")     
        
if __name__ == "__main__":
    main()
# Out:
# The Movie  List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
# Enter Command: list
# 1. A Man and a Gun
# 2. A Star is Born
# 3. City Slickers
# 4. The Grinch Who Stole Christmas
#
# The Movie  List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
# Enter Command: del
# Movie number: 1
# A Man and a Gun was deleted.
#
# The Movie  List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
# Enter Command: list
# 1. A Star is Born
# 2. City Slickers
# 3. The Grinch Who Stole Christmas
#
# The Movie  List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
# Enter Command: add
# Movie Name: it
# it was added to the movie list.
#
# The Movie  List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
# Enter Command: list
# 1. A Star is Born
# ...

# %%
# Create a csv file from a list of lists
import csv
movies = [["What's Up Doc", 1970],
          ["Butch Cassidy and the Sundance Kid", 1978],
          ["The Fugitive", 1990]]

with open("movies.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(movies)

# %%
# Read a csv file into a list
import csv

with open("movies.csv", newline="") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row[0] + " (" + str(row[1]) + ")")
# Out:
# What's Up Doc (1970)
# Butch Cassidy and the Sundance Kid (1978)
# The Fugitive (1990)

# %%
import csv

# our csv file in the current directory as a global variaable
FILENAME = "movies2.csv" 

def write_movies(movie_list):
    with open(FILENAME, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(movie_list)
        
def read_movies():
    movie_list = []
    with open(FILENAME, newline="") as file:
        reader = csv.reader(file)
        for row in reader:
            movie_list.append(row)
    return movie_list

def list_movies(movie_list):
    for i in range(len(movie_list)):
        movie = movie_list[i]
        print(str(i+1) + ". " + movie[0] + " (" + movie[1] + ")")
    print()
    
def add_movie(movie_list):
    name = input("Movie Name: ")
    year = input("Movie Year: ")
    movie = []
    movie.append(name)
    movie.append(year)
    movie_list.append(movie)
    write_movies(movie_list)
    print(movie[0] + " was added.\n")
    
def delete_movie(movie_list):
    number = int(input("Movie number: "))
    if number < 1 or number > len(movie_list):
        print("Invalid movie number.\n")
    else:
        movie = movie_list.pop(number-1)
        write_movies(movie_list)
        print(movie[0] + " was deleted.\n")
                
def display_menu():
    print("The Movie List Program\n")
    print("list - List all movies")
    print("add - Add a movie")
    print("del - Delete a movie")
    print("exit - Exit program\n")
    
def main():
    display_menu()
    movie_list = read_movies()
    print(movie_list)
    command = input("Enter Command: ")
        
    while (command.lower() != "exit"):
        if command.lower() == "list":
            list_movies(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "add":
            add_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "del":
            delete_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "exit":
            continue
        else:
            print("Not a valid command.  Please try again.\n")
            command = input("Enter Command: ")

    print("You'll be back!")     
        
if __name__ == "__main__":
    main()
# Out:
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# [['The Fugitive', '1992'], ['Mr. and Mrs. Smith', '2004']]
# Enter Command: list
# 1. The Fugitive (1992)
# 2. Mr. and Mrs. Smith (2004)
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# Enter Command: add
# Movie Name: it
# Movie Year: 2017
# it was added.
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# Enter Command: list
# 1. The Fugitive (1992)
# 2. Mr. and Mrs. Smith (2004)
# 3. it (2017)
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# Enter Command: exit
# You'll be back!

# %%
# convert a 2-dimensional list to binary file
import pickle

moviesb = [["What's New Pussycat", 1973],
           ["Horton Hears a Who", 2003],
           ["Horse Whisperer", 1984]]

# wb is write binary mode
with open("moviesb.bin", "wb") as file:
    pickle.dump(moviesb, file)

# %%
# read a binary file into a 2-dimensional list
import pickle

# rb is read binary mode
with open("moviesb.bin", "rb") as file:
    movie_list = pickle.load(file)
    print(movie_list)
# Out:
# [["What's New Pussycat", 1973], ['Horton Hears a Who', 2003], ['Horse Whisperer', 1984]]

# %%
# movie list 3.0 program
import pickle

# our csv file in the current directory as a global variaable
FILENAME = "moviesb.bin" 

def write_movies(movie_list):
    with open(FILENAME, "wb") as file:
        pickle.dump(movie_list, file)
        
def read_movies():
    movie_list = []
    with open(FILENAME, "rb") as file:
        movie_list = pickle.load(file)
    return movie_list

def list_movies(movie_list):
    for i in range(len(movie_list)):
        movie = movie_list[i]
        print(str(i+1) + ". " + movie[0] + " (" + str(movie[1]) + ")")
    print()
    
def add_movie(movie_list):
    name = input("Movie Name: ")
    year = input("Movie Year: ")
    movie = []
    movie.append(name)
    movie.append(year)
    movie_list.append(movie)
    write_movies(movie_list)
    print(movie[0] + " was added.\n")
    
def delete_movie(movie_list):
    number = int(input("Movie number: "))
    if number < 1 or number > len(movie_list):
        print("Invalid movie number.\n")
    else:
        movie = movie_list.pop(number-1)
        write_movies(movie_list)
        print(movie[0] + " was deleted.\n")
                
def display_menu():
    print("The Movie List Program\n")
    print("list - List all movies")
    print("add - Add a movie")
    print("del - Delete a movie")
    print("exit - Exit program\n")
    
def main():
    display_menu()
    movie_list = read_movies()
    print(movie_list)
    command = input("Enter Command: ")
        
    while (command.lower() != "exit"):
        if command.lower() == "list":
            list_movies(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "add":
            add_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "del":
            delete_movie(movie_list)
            display_menu()
            command = input("Enter Command: ")
        elif command.lower() == "exit":
            continue
        else:
            print("Not a valid command.  Please try again.\n")
            command = input("Enter Command: ")

    print("You'll be back!")     
        
if __name__ == "__main__":
    main()
# Out:
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# [["What's New Pussycat", 1973], ['Horton Hears a Who', 2003], ['Horse Whisperer', 1984]]
# Enter Command: view
# Not a valid command.  Please try again.
#
# Enter Command: list
# 1. What's New Pussycat (1973)
# 2. Horton Hears a Who (2003)
# 3. Horse Whisperer (1984)
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# Enter Command: add
# Movie Name: me
# Movie Year: 2019
# me was added.
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# exit - Exit program
#
# Enter Command: lsit
# Not a valid command.  Please try again.
#
# Enter Command: list
# 1. What's New Pussycat (1973)
# 2. Horton Hears a Who (2003)
# 3. Horse Whisperer (1984)
# 4. me (2019)
#
# The Movie List Program
#
# list - List all movies
# add - Add a movie
# del - Delete a movie
# ...
